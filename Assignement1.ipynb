# %% [markdown]
# Assignement 1
#
#
# Visualization of the first dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import matplotlib.pyplot as plt
import warnings

# %%
data = pd.read_csv('chicagotaxismall.csv')

# %%
data.head()
# Out:
#                                     Trip ID  \
# 0  7fa9327d2a62e0f1f9eac0f5a4ca0bb5338c22b2
# 1  493354c5b05333aeeb05055a4914c5d38bacef60
# 2  450f3aa6b31aa37cbb7c972f92a9ba31ab506c79
# 3  39100cdb94f6da6b54f71f1d1cdc2ba330f97e09
# 4  36bbb8cf2622b3ce7dde8f6bbaacc903a8403333
#
#                                              Taxi ID    Trip Start Timestamp  \
# 0  03906d62f91d139ab93f74f50d1b208805b7fbb61e8d1e...  01/01/2020 12:00:00 AM
# 1  ca885a78545e9a44a5f365164cfbaca32fee95082b0d4f...  01/01/2020 12:00:00 AM
# 2  81bc2020b8536280419b3e152ad07a0c5b9f53cbb503a0...  01/01/2020 12:00:00 AM
# 3  a548c63608ec50e02a2311a0b6b1b2274995e3637ccb4c...  01/01/2020 12:00:00 AM
# 4  33164e16dd29b1c58cd15cce31df4bfcb75d9903cb66de...  01/01/2020 12:00:00 AM
#
#        Trip End Timestamp  Trip Seconds  Trip Miles  Pickup Census Tract  \
# 0  01/01/2020 12:00:00 AM         178.0        0.48         1.703132e+10
# 1  01/01/2020 12:30:00 AM        1200.0        5.30                  NaN
# ...

# %%
data.describe()
# Out:
#         Trip Seconds     Trip Miles  Pickup Census Tract  \
# count  342158.000000  342291.000000         1.740850e+05
# mean      849.999538       3.559531         1.703143e+10
# std      1687.536139       6.551080         3.445754e+05
# min         0.000000       0.000000         1.703101e+10
# 25%       346.000000       0.500000         1.703108e+10
# 50%       560.000000       1.210000         1.703132e+10
# 75%      1020.000000       3.550000         1.703184e+10
# max     85320.000000     980.500000         1.703198e+10
#
#        Dropoff Census Tract  Pickup Community Area  Dropoff Community Area  \
# count          1.729710e+05          318310.000000           310733.000000
# mean           1.703139e+10              27.542738               23.259445
# std            3.322200e+05              21.328024               18.086949
# min            1.703101e+10               1.000000                1.000000
# ...

# %% [markdown]
# Cosa carina da far vedere anche come check dei dati
#
# Ossia plottiamo la mappa dei pickup e del dropoff

# %%
conversion_describe_varaible = np.array(data.describe())

BBox_pickup =(conversion_describe_varaible[3,-3], conversion_describe_varaible[7, -3],
              conversion_describe_varaible[3, -4], conversion_describe_varaible[7, -4])

second_variable_conversion = np.array(data)
pickup_lat = second_variable_conversion[:,-6]
pickup_long = second_variable_conversion[:, -5]

dropoff_lat = second_variable_conversion[:, -3]
dropoff_long = second_variable_conversion[:, -2]

mappina = plt.imread("chicago.png")

fig, ax = plt.subplots(figsize = (20,10))

ax.scatter(pickup_long, pickup_lat, zorder =1, alpha =0.2, c ='b', s=10)
#ax.scatter(dropoff_long, dropoff_lat, zorder =1, alpha=0.2, c ='r',s =10)
ax.set_title('Plotting spacial pickup data on Chiacago map')
ax.set_xlim(BBox_pickup[0], BBox_pickup[1])
ax.set_ylim(BBox_pickup[2], BBox_pickup[3])

ax.imshow(mappina, zorder = 0, extent = BBox_pickup, aspect ='equal')

# %%
mappina = plt.imread("chicago.png")

fig2, ax = plt.subplots(figsize = (20,10))


ax.scatter(dropoff_long, dropoff_lat, zorder =1, alpha=0.2, c ='r',s =10)
ax.set_title('Plotting spacial pickup data on Chiacago map')
ax.set_xlim(BBox_pickup[0], BBox_pickup[1])
ax.set_ylim(BBox_pickup[2], BBox_pickup[3])

ax.imshow(mappina, zorder = 0, extent = BBox_pickup, aspect ='equal')
